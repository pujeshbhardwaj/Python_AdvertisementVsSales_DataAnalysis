# %% [markdown]
# # Analyzing sales data with respect to advertisement cost
#
# I have downloaded this data from Kaggle which is online platform to get data for practice and calculation, this data is tells us about the investment done for advertisement on TV, Radio and social media for a particular period of time and sales that is obtained from that this data also consist of the type of Influencer used for advertisement.

# %% [markdown]
# ## Downloading the Dataset
#
# I have directly downloaded data from site and uploaded exterally in file section through pd.read_csv

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
# Change this
dataset_url = 'https://www.kaggle.com/tunguz/us-elections-dataset'

# %%
import opendatasets as od
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
# Your Kaggle username:
# Your Kaggle username: pujeshbhardwaj
# Your Kaggle Key: ········
# ...
# 100%|██████████| 133k/133k [00:00<00:00, 39.8MB/s]

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
# Change this
data_dir = './us-elections-dataset'

# %%
import os
os.listdir(data_dir)
# Out:
# ['1976-2020-president.csv', '1976-2020-senate.csv']

# %%
project_name = "zerotopandas_course_project_starter" # change this (use lowercase letters and hyphens only)

# %%
# !pip install jovian --upgrade -q

# %% [markdown]
# ## Data Preparation and Cleaning
#
# I have directly downloaded data from site and uploaded exterally in file section through pd.read_csv
# * Extracted top 200 rows from the data
# * shape of data was (200,5)
# * described the data using .describe()

# %%
import pandas as pd

# %%
dummy_data_url = pd.read_csv('Dummy Data HSS.csv')

# %%
type(dummy_data_url)
# Out:
# pandas.core.frame.DataFrame

# %%
dummy_data_url
# Out:
#         TV      Radio  Social Media Influencer       Sales
# 0     16.0   6.566231      2.907983       Mega   54.732757
# 1     13.0   9.237765      2.409567       Mega   46.677897
# 2     41.0  15.886446      2.913410       Mega  150.177829
# 3     83.0  30.020028      6.922304       Mega  298.246340
# 4     15.0   8.437408      1.405998      Micro   56.594181
# ...    ...        ...           ...        ...         ...
# 4567  26.0   4.472360      0.717090      Micro   94.685866
# 4568  71.0  20.610685      6.545573       Nano  249.101915
# 4569  44.0  19.800072      5.096192      Micro  163.631457
# 4570  71.0  17.534640      1.940873      Macro  253.610411
# 4571  42.0  15.966688      5.046548      Micro  148.202414
#
# [4572 rows x 5 columns]

# %%
dummy_top200 = dummy_data_url.loc[0:200]
dummy_top200 = dummy_top200.copy()
dummy_top200
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 0    16.0   6.566231      2.907983       Mega   54.732757
# 1    13.0   9.237765      2.409567       Mega   46.677897
# 2    41.0  15.886446      2.913410       Mega  150.177829
# 3    83.0  30.020028      6.922304       Mega  298.246340
# 4    15.0   8.437408      1.405998      Micro   56.594181
# ..    ...        ...           ...        ...         ...
# 196  13.0   8.077502      0.013230       Nano   48.303751
# 197  98.0        NaN      6.399730       Nano  345.952838
# 198  12.0   3.556577      0.360015      Micro   37.243272
# 199  11.0   3.785255      1.569645      Micro   45.552511
# 200  89.0        NaN      4.535458      Micro  316.725624
#
# [201 rows x 5 columns]

# %%
dummy_top200.shape
# Out:
# (201, 5)

# %%
dummy_top200.describe()
# Out:
#                TV       Radio  Social Media       Sales
# count  192.000000  199.000000    195.000000  201.000000
# mean    54.484375   18.790081      3.463947  194.284110
# std     27.418222   10.912781      2.289385   99.451075
# min     10.000000    0.226326      0.003177   32.566825
# 25%     30.750000    9.260225      1.563927  106.099593
# 50%     49.000000   18.378401      3.194925  178.374677
# 75%     78.250000   27.079063      4.892583  282.748099
# max    100.000000   47.116293      9.997472  356.582143

# %%
import jovian

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# Here I analyzed my data using libraries seaborn and matplotlib, here i used barplot, countplot, pieplot and scatter plot

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# Count the number of influencer and try to find which influencer is more effective in getting better sales through barpolt

# %%
dummy_top200['Influencer'].value_counts()
# Out:
# Mega     58
# Macro    51
# Micro    46
# Nano     46
# Name: Influencer, dtype: int64

# %%
sns.barplot(x=dummy_top200.Influencer, y=dummy_top200.Sales)
# Out:
# <AxesSubplot:xlabel='Influencer', ylabel='Sales'>

# %% [markdown]
# This time created diffrent array of counts of influencr and used same in making pieplot

# %%
Influencer_counts = dummy_top200.Influencer.value_counts()
Influencer_counts
# Out:
# Mega     58
# Macro    51
# Micro    46
# Nano     46
# Name: Influencer, dtype: int64

# %%
plt.pie(Influencer_counts, labels= Influencer_counts.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
dummy_top200
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 0    16.0   6.566231      2.907983       Mega   54.732757
# 1    13.0   9.237765      2.409567       Mega   46.677897
# 2    41.0  15.886446      2.913410       Mega  150.177829
# 3    83.0  30.020028      6.922304       Mega  298.246340
# 4    15.0   8.437408      1.405998      Micro   56.594181
# ..    ...        ...           ...        ...         ...
# 196  13.0   8.077502      0.013230       Nano   48.303751
# 197  98.0        NaN      6.399730       Nano  345.952838
# 198  12.0   3.556577      0.360015      Micro   37.243272
# 199  11.0   3.785255      1.569645      Micro   45.552511
# 200  89.0        NaN      4.535458      Micro  316.725624
#
# [201 rows x 5 columns]

# %%
sns.countplot(y=dummy_top200.Influencer)
plt.xticks(rotation=75);
plt.title('count of influencer')
plt.ylabel(None);

# %% [markdown]
# Made scatter plot to understand the variation of sales and tv advertisement with differentiating influencer with different colors

# %%
dummy_top200
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 0    16.0   6.566231      2.907983       Mega   54.732757
# 1    13.0   9.237765      2.409567       Mega   46.677897
# 2    41.0  15.886446      2.913410       Mega  150.177829
# 3    83.0  30.020028      6.922304       Mega  298.246340
# 4    15.0   8.437408      1.405998      Micro   56.594181
# ..    ...        ...           ...        ...         ...
# 196  13.0   8.077502      0.013230       Nano   48.303751
# 197  98.0        NaN      6.399730       Nano  345.952838
# 198  12.0   3.556577      0.360015      Micro   37.243272
# 199  11.0   3.785255      1.569645      Micro   45.552511
# 200  89.0        NaN      4.535458      Micro  316.725624
#
# [201 rows x 5 columns]

# %%
sns.scatterplot(x = dummy_top200.Sales, y  = dummy_top200.TV, hue=dummy_top200.Influencer);

# %% [markdown]
# simple line plot of radio advertisement

# %%
dummy_top200.Radio.plot();

# %% [markdown]
# ## Asking and Answering Questions
#
# Applying sum functions to clean ,sort, filter data and done some calculation

# %% [markdown]
# #### Q1: Show the original data and extract top 100 rows and create separate data

# %%
dummy_data_url
# Out:
#         TV      Radio  Social Media Influencer       Sales
# 0     16.0   6.566231      2.907983       Mega   54.732757
# 1     13.0   9.237765      2.409567       Mega   46.677897
# 2     41.0  15.886446      2.913410       Mega  150.177829
# 3     83.0  30.020028      6.922304       Mega  298.246340
# 4     15.0   8.437408      1.405998      Micro   56.594181
# ...    ...        ...           ...        ...         ...
# 4567  26.0   4.472360      0.717090      Micro   94.685866
# 4568  71.0  20.610685      6.545573       Nano  249.101915
# 4569  44.0  19.800072      5.096192      Micro  163.631457
# 4570  71.0  17.534640      1.940873      Macro  253.610411
# 4571  42.0  15.966688      5.046548      Micro  148.202414
#
# [4572 rows x 5 columns]

# %%
dummy_top100 = dummy_data_url.loc[0:100]
dummy_top100 = dummy_top100.copy()
dummy_top100
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 0    16.0   6.566231      2.907983       Mega   54.732757
# 1    13.0   9.237765      2.409567       Mega   46.677897
# 2    41.0  15.886446      2.913410       Mega  150.177829
# 3    83.0  30.020028      6.922304       Mega  298.246340
# 4    15.0   8.437408      1.405998      Micro   56.594181
# ..    ...        ...           ...        ...         ...
# 96   20.0   3.934783      0.328470       Nano   72.625903
# 97   49.0  24.359044      3.797367       Nano  174.198139
# 98   29.0  11.213689      0.558837      Macro   98.999638
# 99    NaN   7.635819      1.554146      Macro   56.186730
# 100  39.0  13.187256      2.766352      Macro  140.415286
#
# [101 rows x 5 columns]

# %%
dummy_top100.shape
# Out:
# (101, 5)

# %% [markdown]
# #### Q2: Access a specific row of data, through the .loc method, Also use the .head and .tail methods to view the first or last few rows of data

# %%
dummy_top100.loc[100]
# Out:
# TV                    39.0
# Radio            13.187256
# Social Media      2.766352
# Influencer           Macro
# Sales           140.415286
# Name: 100, dtype: object

# %%
dummy_top100.head(5)
# Out:
#      TV      Radio  Social Media Influencer       Sales
# 0  16.0   6.566231      2.907983       Mega   54.732757
# 1  13.0   9.237765      2.409567       Mega   46.677897
# 2  41.0  15.886446      2.913410       Mega  150.177829
# 3  83.0  30.020028      6.922304       Mega  298.246340
# 4  15.0   8.437408      1.405998      Micro   56.594181

# %%
dummy_top100.tail(10)
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 91   32.0   0.758067      2.359200       Mega  112.269694
# 92   29.0   2.172596      4.208325       Mega  103.634866
# 93   72.0  25.406596      3.215455      Micro  262.401171
# 94   14.0   8.001266      4.187834      Micro   51.442984
# 95   95.0  38.415225      7.673637      Micro  336.760633
# 96   20.0   3.934783      0.328470       Nano   72.625903
# 97   49.0  24.359044      3.797367       Nano  174.198139
# 98   29.0  11.213689      0.558837      Macro   98.999638
# 99    NaN   7.635819      1.554146      Macro   56.186730
# 100  39.0  13.187256      2.766352      Macro  140.415286

# %% [markdown]
# #### Q3: TODO - Finding top sales greater than 200, and arranging in decreasing order

# %%
Top_sales = dummy_top100[dummy_top100.Sales > 200]

# %%
Top_sales
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 3    83.0  30.020028      6.922304       Mega  298.246340
# 8    76.0  24.648898      7.130116      Macro  270.189400
# 10   62.0  24.345189      5.151483       Nano  224.961019
# 12   64.0  20.240424      3.921148      Micro  229.632381
# 13    NaN  22.351667      3.031815       Mega  276.165351
# 16   60.0  22.353721      0.940802       Mega  212.764397
# 18  100.0  36.116091      3.674296      Macro  353.804639
# 19   92.0  40.736990      4.636564       Nano  329.350540
# 21   78.0  35.568224      2.832450      Macro  276.401340
# 23   99.0  37.263819      6.886535       Nano  349.861575
# 24   75.0  20.348988      1.227180      Micro  272.250108
# 26    NaN  34.111674      4.624148       Nano  342.913372
# 30   67.0  24.137616      5.573093       Mega  234.851025
# 31   90.0  29.021017      6.431995      Micro  323.032183
# 33   81.0  27.335775      5.263650      Micro  290.777574
# ...

# %%
Top_sales.sort_values('Sales' , ascending=False)
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 18  100.0  36.116091      3.674296      Macro  353.804639
# 43   98.0  37.570952      8.529604       Mega  351.773068
# 68   99.0  30.140569      6.546158       Mega  351.359890
# 23   99.0  37.263819      6.886535       Nano  349.861575
# 77   98.0  33.055159      6.063458       Mega  349.745296
# 82   99.0  37.717805      3.590086       Nano  349.423974
# 86   97.0  39.232306      3.698661       Nano  345.313164
# 26    NaN  34.111674      4.624148       Nano  342.913372
# 95   95.0  38.415225      7.673637      Micro  336.760633
# 85   94.0  47.116293      9.322958      Micro  336.593420
# 89   93.0  33.059451      5.789298      Micro  335.209070
# 19   92.0  40.736990      4.636564       Nano  329.350540
# 51   91.0  40.108527      7.236170       Mega  326.381712
# 31   90.0  29.021017      6.431995      Micro  323.032183
# 61   91.0  25.045557      6.109370      Macro  322.100496
# ...

# %% [markdown]
# #### Q4: TODO - ask a question here and answer it below

# %%
influencer_total = dummy_top100.groupby('Influencer')[['TV','Radio']].sum()

# %%
influencer_total
# Out:
#                 TV       Radio
# Influencer
# Macro       1116.0  385.202225
# Mega        1682.0  656.622058
# Micro       1169.0  406.328123
# Nano        1088.0  441.386917

# %%
influencer_mean = dummy_top100.groupby('Influencer')[['TV','Radio']].mean()
influencer_mean
# Out:
#                    TV      Radio
# Influencer
# Macro       53.142857  16.747923
# Mega        49.470588  18.239502
# Micro       55.666667  19.348958
# Nano        54.400000  21.018425

# %% [markdown]
# #### Q5: TODO - Calculating the total profit

# %%
dummy_top100
# Out:
#        TV      Radio  Social Media Influencer       Sales
# 0    16.0   6.566231      2.907983       Mega   54.732757
# 1    13.0   9.237765      2.409567       Mega   46.677897
# 2    41.0  15.886446      2.913410       Mega  150.177829
# 3    83.0  30.020028      6.922304       Mega  298.246340
# 4    15.0   8.437408      1.405998      Micro   56.594181
# ..    ...        ...           ...        ...         ...
# 96   20.0   3.934783      0.328470       Nano   72.625903
# 97   49.0  24.359044      3.797367       Nano  174.198139
# 98   29.0  11.213689      0.558837      Macro   98.999638
# 99    NaN   7.635819      1.554146      Macro   56.186730
# 100  39.0  13.187256      2.766352      Macro  140.415286
#
# [101 rows x 5 columns]

# %%
total_cost = (dummy_top100.TV + dummy_top100.Radio).sum()
total_cost
# Out:
# 6839.098232855999

# %%
total_sale = dummy_top100.Sales.sum()
total_sale
# Out:
# 19049.55280915

# %%
profit = total_sale-total_cost
profit
# Out:
# 12210.454576294

# %% [markdown]
# ## Inferences and Conclusion
#
# From the above summary we can say that
# * There is no effect of influencer on sales because the highest count of influencer was mega influencer but influencer that contributed the most in sales was nano influencer.
# * Investment done on marketing through advertisement on different segments ultimately contributed in higher sales and finally in profit.

# %% [markdown]
# ## References and Future Work
#
# this data can be further used for just practicing analysis due to no proper authenticity of data
